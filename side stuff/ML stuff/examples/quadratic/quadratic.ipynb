# %%
import tensorflow as tf
from tensorflow import keras

import pandas as pd
import numpy as np

# %%
train_df = pd.read_csv('./data/train.csv')
np.random.shuffle(train_df.values)

# %%
model = keras.Sequential([
	keras.layers.Dense(8, input_shape=(2,), activation='relu'),
	keras.layers.Dense(8, activation='relu'),
	keras.layers.Dense(8, activation='relu'),
	keras.layers.Dense(8, activation='relu'),
	keras.layers.Dense(8, activation='relu'),
	keras.layers.Dense(2, activation='sigmoid')])

# %%
model.compile(optimizer="adam", 
                #loss function is binary cross entropy, cuz we're doing binary classification
                #from_logits=True cuz our output is not normalized???
                loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
                metrics=["accuracy"])

# %%
attributes = np.column_stack((train_df.x.values, train_df.y.values))

model.fit(attributes, train_df.color.values, batch_size=4, epochs=5)
# Out:
# Train on 4000 samples
# Epoch 1/5
# 4000/4000 [==============================] - 1s 292us/sample - loss: 0.3485 - accuracy: 0.9640
# Epoch 2/5
# 4000/4000 [==============================] - 1s 299us/sample - loss: 0.3430 - accuracy: 0.9705
# Epoch 3/5
# 4000/4000 [==============================] - 1s 301us/sample - loss: 0.3133 - accuracy: 1.0000
# Epoch 4/5
# 4000/4000 [==============================] - 1s 293us/sample - loss: 0.3133 - accuracy: 1.0000
# Epoch 5/5
# 4000/4000 [==============================] - 1s 330us/sample - loss: 0.3133 - accuracy: 1.0000

# %%
test_df = pd.read_csv("./data/test.csv")
test_x = np.column_stack((test_df.x.values, test_df.y.values))

# %%
model.evaluate(test_x, test_df.color.values)
# Out:
# 1000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# [0.3132813467979431, 1.0]
