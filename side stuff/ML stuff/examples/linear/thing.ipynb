# %%
import tensorflow as tf
from tensorflow import keras

import pandas as pd
import numpy as np

# %%
train_df = pd.read_csv('./data/train.csv')
np.random.shuffle(train_df.values)

# %%
model = keras.Sequential([
	keras.layers.Dense(32, input_shape=(2,), activation='relu'),
	keras.layers.Dense(32, activation='relu'),
	keras.layers.Dense(2, activation='sigmoid')])
# Out:
# 2021-12-25 23:39:58.546184: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-12-25 23:39:58.548495: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 8. Tune using inter_op_parallelism_threads for best performance.

# %%
model.compile(optimizer="adam", 
                #loss function is binary cross entropy, cuz we're doing binary classification
                #from_logits=True cuz our output is not normalized???
                loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
                metrics=["accuracy"])

# %%
attributes = np.column_stack((train_df.x.values, train_df.y.values))

model.fit(attributes, train_df.color.values, batch_size=4, epochs=10)
# Out:
# Train on 4000 samples
# Epoch 1/10
# 4000/4000 [==============================] - 1s 271us/sample - loss: 0.3133 - accuracy: 1.0000
# Epoch 2/10
# 4000/4000 [==============================] - 1s 297us/sample - loss: 0.3133 - accuracy: 1.0000
# Epoch 3/10
# 4000/4000 [==============================] - 1s 275us/sample - loss: 0.3133 - accuracy: 1.0000
# Epoch 4/10
# 4000/4000 [==============================] - 1s 253us/sample - loss: 0.3133 - accuracy: 1.0000
# Epoch 5/10
# 4000/4000 [==============================] - 1s 264us/sample - loss: 0.3136 - accuracy: 0.9998
# Epoch 6/10
# 4000/4000 [==============================] - 1s 284us/sample - loss: 0.3133 - accuracy: 1.0000
# Epoch 7/10
# 4000/4000 [==============================] - 1s 260us/sample - loss: 0.3133 - accuracy: 1.0000
# Epoch 8/10
# 4000/4000 [==============================] - 1s 226us/sample - loss: 0.3133 - accuracy: 1.0000
# Epoch 9/10
# 4000/4000 [==============================] - 1s 254us/sample - loss: 0.3133 - accuracy: 1.0000
# Epoch 10/10
# 4000/4000 [==============================] - 1s 255us/sample - loss: 0.3135 - accuracy: 0.9998

# %%
test_df = pd.read_csv("./data/test.csv")
test_x = np.column_stack((test_df.x.values, test_df.y.values))

# %%
model.evaluate(test_x, test_df.color.values)
# Out:
# 1000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# [0.3132629837989807, 1.0]

# %%
print(model.predict_classes(np.column_stack(([0], [0.09]))))
# Out:
# [0]
